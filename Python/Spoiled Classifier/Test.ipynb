# %%
import DataSet
import matplotlib.pyplot as plt

# %%
objDataSet = DataSet.DataSet('DataSet.csv','TestTrain.hdf5',100,100)
objDataSet.CreateHDF5DataSet()
# Out:
# 2 2
# Processing: 1 of 2 - 50.0% - Data\banana_1.jpgLabela: [1, 0]
# Processing: 2 of 2 - 100.0% - Data\morkov_1.jpgLabela: [0, 1]

# %%
Features = []
Labels = []
for item in objDataSet.GenerateTrainingData(2):
    print(item[0][0].shape)
    print(item[1][0])
    plt.imshow(item[0][0])
    Features.append(item[0][0])
    Labels.append(item[0][0])
    plt.show()
    print(item[0][1].shape)
    print(item[1][1])
    plt.imshow(item[0][1])
    Features.append(item[0][1])
    Labels.append(item[1][1])
    plt.show()
    count+=1
# Out:
# (100, 100, 3)
# [ 1.  0.]
# (100, 100, 3)
# [ 0.  1.]

# %%
Labels
# Out:
# [array([[[ 0.82366431,  0.80405647,  0.82758588],
#          [ 0.81295371,  0.80511057,  0.82471842],
#          [ 0.81250197,  0.80465883,  0.82426667],
#          ...,
#          [ 0.76185095,  0.77753723,  0.82067454],
#          [ 0.75618196,  0.78363293,  0.82284862],
#          [ 0.75945097,  0.78690195,  0.82611763]],
#
#         [[ 0.81487685,  0.79526901,  0.81879842],
#          [ 0.82148707,  0.80211449,  0.82556552],
#          [ 0.81949806,  0.80773336,  0.83518434],
#          ...,
#          [ 0.74917644,  0.77662742,  0.81584316],
#          [ 0.75886118,  0.77454746,  0.81768471],
#          [ 0.75870746,  0.77957022,  0.82662904]],
#
#         [[ 0.81279999,  0.80495685,  0.8245647 ],
#          [ 0.80953723,  0.8016941 ,  0.82130194],
#          [ 0.81615686,  0.80439216,  0.83184314],
#          ...,
#          [ 0.7687059 ,  0.78439218,  0.82752943],
#          [ 0.75217253,  0.7678588 ,  0.81099606],
#          [ 0.74959999,  0.76528627,  0.80842352]],
#
# ...
